# %% [markdown]
# # 8	Mezcla para un sistema de cómputo
# Un centro de datos necesita adquirir una combinación de dos tipos de servidores.
# Característica	Servidor A	Servidor B
# Costo	S/ 2 000	S/ 1 200
# RAM	64 GB	32 GB
# Procesamiento	16 unidades	10 unidades
# Se requiere al menos:
# • 320 GB de RAM.
# • 100 unidades de procesamiento.
# ¿Cuál de las siguientes expresiones representa correctamente la restricción de procesamiento?
# A.  16x + 10y ≤ 100	C.  64x + 32y ≥ 100
# B.  16x + 10y ≥ 100	D.  16x − 10y ≥ 100

# %%
from IPython.display import HTML, display

html = r'''
<div style="background:#000; color:white; padding:28px; border-radius:18px; text-align:center; font-family:Arial, sans-serif; overflow:hidden;">
  <h1 style="margin-bottom:8px;"> ¡Recuerden que serán unos grandes profesionales! </h1>
  <p style="font-size:20px; margin-top:0;">Confíen en su proceso, sigan aprendiendo y nunca dejen de superarse.</p>

  <div class="garden">
    <div class="flower f1">
      <div class="stem"></div>
      <div class="leaf l1"></div><div class="leaf l2"></div>
      <div class="head">
        <span class="petal p1"></span><span class="petal p2"></span><span class="petal p3"></span><span class="petal p4"></span>
        <span class="petal p5"></span><span class="petal p6"></span><span class="petal p7"></span><span class="petal p8"></span>
        <span class="center"></span>
      </div>
    </div>
    <div class="flower f2">
      <div class="stem"></div>
      <div class="leaf l1"></div><div class="leaf l2"></div>
      <div class="head">
        <span class="petal p1"></span><span class="petal p2"></span><span class="petal p3"></span><span class="petal p4"></span>
        <span class="petal p5"></span><span class="petal p6"></span><span class="petal p7"></span><span class="petal p8"></span>
        <span class="center"></span>
      </div>
    </div>
    <div class="flower f3">
      <div class="stem"></div>
      <div class="leaf l1"></div><div class="leaf l2"></div>
      <div class="head">
        <span class="petal p1"></span><span class="petal p2"></span><span class="petal p3"></span><span class="petal p4"></span>
        <span class="petal p5"></span><span class="petal p6"></span><span class="petal p7"></span><span class="petal p8"></span>
        <span class="center"></span>
      </div>
    </div>
    <div class="flower f4">
      <div class="stem"></div>
      <div class="leaf l1"></div><div class="leaf l2"></div>
      <div class="head">
        <span class="petal p1"></span><span class="petal p2"></span><span class="petal p3"></span><span class="petal p4"></span>
        <span class="petal p5"></span><span class="petal p6"></span><span class="petal p7"></span><span class="petal p8"></span>
        <span class="center"></span>
      </div>
    </div>
    <div class="flower f5">
      <div class="stem"></div>
      <div class="leaf l1"></div><div class="leaf l2"></div>
      <div class="head">
        <span class="petal p1"></span><span class="petal p2"></span><span class="petal p3"></span><span class="petal p4"></span>
        <span class="petal p5"></span><span class="petal p6"></span><span class="petal p7"></span><span class="petal p8"></span>
        <span class="center"></span>
      </div>
    </div>
  </div>

  <div style="font-size:24px; font-weight:bold; margin-top:10px;"> Para la siguiente clase: INSTALAR POWER BI</div>
</div>

<style>
.garden{height:410px; display:flex; justify-content:space-evenly; align-items:flex-end; gap:15px; margin-top:15px;}
.flower{position:relative; width:150px; height:340px; transform-origin:bottom center;}
.stem{position:absolute; left:72px; bottom:20px; width:8px; height:205px; background:#198c19; border-radius:8px;}
.leaf{position:absolute; width:70px; height:28px; background:#35c735; border-radius:100% 0 100% 0; transform-origin:100% 50%;}
.l1{left:12px; bottom:95px; transform:rotate(28deg);}
.l2{left:68px; bottom:145px; transform:rotate(205deg);}
.head{position:absolute; width:135px; height:135px; left:8px; top:18px; animation:headSway 3s ease-in-out infinite;}
.center{position:absolute; width:44px; height:44px; background:#f28c00; border:4px solid #8b4513; border-radius:50%; left:45px; top:45px; z-index:3;}
.petal{position:absolute; width:54px; height:30px; background:#ffd700; border:2px solid #ff9d00; border-radius:60%; left:40px; top:52px; transform-origin:27px 15px;}
.p1{transform:translateY(-46px) rotate(90deg)}
.p2{transform:translate(32px,-31px) rotate(135deg)}
.p3{transform:translateX(45px) rotate(180deg)}
.p4{transform:translate(32px,31px) rotate(225deg)}
.p5{transform:translateY(45px) rotate(270deg)}
.p6{transform:translate(-32px,31px) rotate(315deg)}
.p7{transform:translateX(-45px) rotate(0deg)}
.p8{transform:translate(-32px,-31px) rotate(45deg)}

@keyframes leafWave1{0%,100%{transform:rotate(28deg)}50%{transform:rotate(48deg)}}
@keyframes leafWave2{0%,100%{transform:rotate(205deg)}50%{transform:rotate(185deg)}}
@keyframes petalPulse{0%,100%{filter:brightness(1); scale:1}50%{filter:brightness(1.35); scale:1.18}}
@keyframes flowerWave{0%,100%{transform:rotate(0deg)}50%{transform:rotate(5deg)}}
@keyframes headSway{0%,100%{transform:rotate(-2deg)}50%{transform:rotate(2deg)}}

/* Cada flor comienza en un momento distinto */
.f1{animation:flowerWave 2.8s ease-in-out infinite 0s}
.f2{animation:flowerWave 2.8s ease-in-out infinite .8s}
.f3{animation:flowerWave 2.8s ease-in-out infinite 1.6s}
.f4{animation:flowerWave 2.8s ease-in-out infinite 2.4s}
.f5{animation:flowerWave 2.8s ease-in-out infinite 3.2s}

/* Hojita por hojita */
.f1 .l1{animation:leafWave1 2.3s ease-in-out infinite 0s}.f1 .l2{animation:leafWave2 2.3s ease-in-out infinite .35s}
.f2 .l1{animation:leafWave1 2.3s ease-in-out infinite .8s}.f2 .l2{animation:leafWave2 2.3s ease-in-out infinite 1.15s}
.f3 .l1{animation:leafWave1 2.3s ease-in-out infinite 1.6s}.f3 .l2{animation:leafWave2 2.3s ease-in-out infinite 1.95s}
.f4 .l1{animation:leafWave1 2.3s ease-in-out infinite 2.4s}.f4 .l2{animation:leafWave2 2.3s ease-in-out infinite 2.75s}
.f5 .l1{animation:leafWave1 2.3s ease-in-out infinite 3.2s}.f5 .l2{animation:leafWave2 2.3s ease-in-out infinite 3.55s}

/* Pétalo por pétalo en cada flor */
.flower .p1{animation:petalPulse 2.4s ease-in-out infinite 0s}
.flower .p2{animation:petalPulse 2.4s ease-in-out infinite .18s}
.flower .p3{animation:petalPulse 2.4s ease-in-out infinite .36s}
.flower .p4{animation:petalPulse 2.4s ease-in-out infinite .54s}
.flower .p5{animation:petalPulse 2.4s ease-in-out infinite .72s}
.flower .p6{animation:petalPulse 2.4s ease-in-out infinite .90s}
.flower .p7{animation:petalPulse 2.4s ease-in-out infinite 1.08s}
.flower .p8{animation:petalPulse 2.4s ease-in-out infinite 1.26s}

/* Desfase adicional para que las flores vayan una detrás de otra */
.f2 .petal{animation-delay:calc(var(--d, 0s) + .8s)}
.f3 .petal{animation-delay:calc(var(--d, 0s) + 1.6s)}
.f4 .petal{animation-delay:calc(var(--d, 0s) + 2.4s)}
.f5 .petal{animation-delay:calc(var(--d, 0s) + 3.2s)}

.p1{--d:0s}.p2{--d:.18s}.p3{--d:.36s}.p4{--d:.54s}.p5{--d:.72s}.p6{--d:.90s}.p7{--d:1.08s}.p8{--d:1.26s}
</style>
'''

display(HTML(html))
